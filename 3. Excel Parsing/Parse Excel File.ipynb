# %%
import openpyxl
import pandas as pd

# %%
report_path = "./data/risk_analysis_report.xlsx"

# %%
wb = openpyxl.load_workbook(report_path)

sheet_names = wb.sheetnames
sheet_names
# Out:
# ['View 1_Summary',
#  'View 1_DNCA_97_positionStd_20',
#  'View 1_DNCA_97_positionStd_202',
#  'View 1_DNCA_58_positionStd_20',
#  'View 1_DNCA_58_positionStd_202',
#  'View 1_DNCA_57_positionStd_20',
#  'View 1_DNCA_57_positionStd_202',
#  'View 1_DNCA_97_CountryofRiskD',
#  'Statistic Definitions',
#  'Risk Settings']

# %%
sheet_name = 'View 1_DNCA_97_positionStd_20'
df = pd.read_excel(report_path, sheet_name=sheet_name)

# %%
df.head(100)
# Out:
#     Unnamed: 0 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0          NaN        NaN            NaN        NaN        NaN            NaN
# 1          NaN        NaN            NaN        NaN        NaN            NaN
# 2          NaN        NaN            NaN        NaN        NaN            NaN
# 3          NaN        NaN            NaN        NaN        NaN            NaN
# 4          NaN        NaN            NaN        NaN        NaN            NaN
# ..         ...        ...            ...        ...        ...            ...
# 95         NaN          0  Instrument 76     ID A76      -1540      -739200.0
# 96         NaN          0  Instrument 77     ID A77      -1540     -1478400.0
# 97         NaN          0  Instrument 78     ID A78      -1123              0
# 98         NaN          0  Instrument 79     ID A79       -140      -327600.0
# 99         NaN          0  Instrument 80     ID A80       -140 -806400.000939
#
# ...
